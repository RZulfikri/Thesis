# %% [markdown]
# # v8 TRAIN — seed 0 (faktorial alignment × loss)
# Shell tipis: semua logika di `v8_lib.py`. File ini KHUSUS seed **0** (1 file per runtime → tak konflik antar-runtime paralel).
# Jalankan Run-all. Checkpoint → Google Drive; resume otomatis (gate `perf.json`).

# %% [markdown]
# ## 1. Clone repo (branch main)

# %%
from google.colab import userdata
import os, sys, subprocess
from pathlib import Path
TOKEN = userdata.get('GITHUB_TOKEN'); os.environ['GITHUB_TOKEN'] = TOKEN
REPO = Path('/content/Thesis'); URL = f'https://{TOKEN}@github.com/RZulfikri/Thesis.git'
if not REPO.exists():
    subprocess.run(['git','clone','--branch','main',URL,str(REPO)], check=True)
else:
    subprocess.run(['git','-C',str(REPO),'fetch','origin','main'], check=True)
    subprocess.run(['git','-C',str(REPO),'checkout','main'], check=True)
    subprocess.run(['git','-C',str(REPO),'pull','origin','main'], check=True)
subprocess.run(['git','-C',str(REPO),'config','user.email','colab@thesis.local'])
subprocess.run(['git','-C',str(REPO),'config','user.name','Colab Runner'])
sys.path.insert(0, str(REPO/'3DCNN'/'collab'))
print('clone OK ->', REPO)
# Out:
# clone OK -> /content/Thesis

# %% [markdown]
# ## 2. Setup (Drive + dataset + autotune GPU)

# %%
import v8_lib as L
L.setup(github_token=os.environ['GITHUB_TOKEN'])
# Out:
# Mounted at /content/drive
# Device: cuda | REPO_DIR=/content/Thesis
# RUNS_DIR (Drive): /content/drive/MyDrive/PointNetPalm/runs/v8_factorial
# ANA_DIR (git):    /content/Thesis/3DCNN/analysis/v8_factorial_20260628_034622
# [deps] install: open3d ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 71.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 73.0 MB/s eta 0:00:00
# [data] RESTORE dataset dari Drive cache (tanpa regenerate) ...
# [data] restored: 2131 frame
# [data] siap: 2131 frame
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (95.6 GB) | AMP=bf16 | BS(fixed)=3072 | workers=8 | REPEAT=24 | N_POINTS=8192
# [LowData-Sessions] train   : 88 sesi
# [LowData-Sessions] val     : 22 sesi
# [LowData-Sessions] test    : 22 sesi
# [LowData-Sessions] holdout : 33 sesi
#   train   : 11 subjek, 88 sesi
#   val     : 11 subjek, 22 sesi
#   test    : 11 subjek, 22 sesi
#   holdout : 11 subjek, 33 sesi
# [setup] selesai.

# %% [markdown]
# ## 3. Training — 12 config × seed 0

# %%
L.train(seeds=[0])   # 12 config (A0..A5 × softmax/arcface) untuk seed 0
# Out:
# Streaming output truncated to the last 5000 lines.
#  33%|███▎      | 2/6 [00:03<00:07,  1.84s/batch, acc=1.000, loss=0.0000]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=1.000, loss=0.0000]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0000]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0000]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0000]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.932, loss=1.8285]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.932, loss=1.8285]
#
# P2 Epoch 029/30  train=0.0003  triplet=0.0003  val_loss=1.8285  val_eer=0.0296  lr=2.09e-06  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0011]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=1.000, loss=0.0011]
#  33%|███▎      | 2/6 [00:03<00:07,  1.85s/batch, acc=1.000, loss=0.0011]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0011]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0011]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0011]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0011]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.923, loss=1.8948]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.923, loss=1.8948]
#
# P2 Epoch 030/30  train=0.0003  triplet=0.0003  val_loss=1.8948  val_eer=0.0351  lr=1.00e-06  t=11.8s
# [v7.2.0 perf] train_wall=1791.8s  peak_gpu=78048.5MB  n_train_frames=871
#
# Training selesai. Best pair_eer = 0.0222
#
# ============================================================
# TRAIN A5_softmax | repr=align_anatomical | loss=arcface_true m=0.0 | seed=0
# ============================================================
# $ PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True /usr/bin/python3 /content/Thesis/3DCNN/train.py --data_dir /content/Thesis/3DCNN/dataset --output_dir /content/drive/MyDrive/PointNetPalm/runs/v8_factorial/A5_softmax/seed_0 --seed 0 --fixed_split --frames-per-session 1 --frame-mode all --repr-mode align_anatomical --loss arcface_true --arcface-variant true --arcface-margin 0.0 --arcface-scale 30.0 --val-metric pair_eer --no-early-stop --epochs 120 --finetune_epochs 30 --lr 0.004 --finetune_lr 0.0004 --batch_size 3072 --n_points 8192 --num_workers 8 --repeat 24 --amp bf16 --preload-augment --siamese-mode concat
#
# 2026-06-28 08:47:58.904077: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-28 08:47:58.936899: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Auto-config] 96GB class (NVIDIA RTX PRO 6000 Blackwell Server Edition, CC=12.0) | VRAM=95.6GB | CPU=48 core | RAM=176.9GB
#               batch_size=3072, num_workers=8, n_points=8192, lr=0.002, finetune_lr=0.0002
# Device: cuda
# [Seed] RNG seeds set to 0
# [CUDA] cudnn.benchmark=True, TF32=enabled
# Layout data: frame (single-frame)
#
# [v7.2.0] Low-data ALL-FRAME regime: repr_mode=align_anatomical
# [LowData-Sessions] train   : 88 sesi
# [LowData-Sessions] val     : 22 sesi
# [LowData-Sessions] test    : 22 sesi
# [LowData-Sessions] holdout : 33 sesi
# [LowData-AllFrames] train   : 871 frames
# [LowData-AllFrames] val     : 220 frames
# [LowData-AllFrames] test    : 220 frames
# [LowData-AllFrames] holdout : 330 frames
#
# Split (low-data, deterministic chronological):
#   aisah              train= 80  val= 20  test= 20  holdout=30
#   alji               train= 80  val= 20  test= 20  holdout=30
#   chrys              train= 80  val= 20  test= 20  holdout=30
#   fadhil             train= 80  val= 20  test= 20  holdout=30
#   feby               train= 80  val= 20  test= 20  holdout=30
#   gede               train= 80  val= 20  test= 20  holdout=30
#   nola               train= 71  val= 20  test= 20  holdout=30
#   rahmat             train= 80  val= 20  test= 20  holdout=30
#   reysa              train= 80  val= 20  test= 20  holdout=30
#   taufik             train= 80  val= 20  test= 20  holdout=30
#   yanuar             train= 80  val= 20  test= 20  holdout=30
#
# splits.json disimpan di: /content/drive/MyDrive/PointNetPalm/runs/v8_factorial/A5_softmax/seed_0/splits.json
# [Dataset] mode=arcface_true  repeat=24  preload_augment=True
# PalmFrameDataset (PRELOAD): precomputing 20904 augmented variants ...
#   Preload selesai: 20904 items, ~3920.5 MB di RAM
# PalmFrameDataset: 220 unique frames, 11 labels, repeat=1 → len(dataset)=220
# [Loss] margin head 'arcface_true' (variant=true, m=0.0, s=30.0, K=3); criterion=cross-entropy
# [Siamese] mode = concat, loss = arcface_true, aux_loss = False
# [ValPairMetric] Preloading 220 frames for val pair computation...
# [ValPairMetric] 2190 pairs ready (2090 genuine, 100 impostor)
#
# --- Phase 1: Main Training (lr=4.00e-03, epochs=120) ---
# [AMP] Mixed precision: bf16 (no GradScaler, optimal H100/A100)
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:10<?, ?batch/s, acc=0.110, loss=4.3362]
#  17%|█▋        | 1/6 [00:10<00:52, 10.48s/batch, acc=0.110, loss=4.3362]
#  33%|███▎      | 2/6 [00:11<00:20,  5.18s/batch, acc=0.110, loss=4.3362]
#  50%|█████     | 3/6 [00:13<00:10,  3.64s/batch, acc=0.110, loss=4.3362]
#  67%|██████▋   | 4/6 [00:15<00:05,  2.91s/batch, acc=0.110, loss=4.3362]
#  83%|████████▎ | 5/6 [00:17<00:02,  2.51s/batch, acc=0.110, loss=4.3362]
# 100%|██████████| 6/6 [00:19<00:00,  2.27s/batch, acc=0.110, loss=4.3362]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:03<?, ?batch/s, acc=0.091, loss=5.9138]
# 100%|██████████| 1/1 [00:03<00:00,  3.66s/batch, acc=0.091, loss=5.9138]
#
# P1 Epoch 001/120  train=4.0935  triplet=4.0935  val_loss=5.9138  val_eer=0.4995  lr=4.00e-03  t=26.2s
#   [VRAM Peak Ep1] allocated=76.2GB  reserved=80.5GB  (85% of 95GB)
#   Terbaik: val_eer=0.4995 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.345, loss=2.5833]
#  17%|█▋        | 1/6 [00:02<00:11,  2.38s/batch, acc=0.345, loss=2.5833]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=0.345, loss=2.5833]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.345, loss=2.5833]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.345, loss=2.5833]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.345, loss=2.5833]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.345, loss=2.5833]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.091, loss=6.6726]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.091, loss=6.6726]
#
# P1 Epoch 002/120  train=1.9540  triplet=1.9540  val_loss=6.6726  val_eer=0.5107  lr=4.00e-03  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.579, loss=1.3555]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=0.579, loss=1.3555]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=0.579, loss=1.3555]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.579, loss=1.3555]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.579, loss=1.3555]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.579, loss=1.3555]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.579, loss=1.3555]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.127, loss=5.2910]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.127, loss=5.2910]
#
# P1 Epoch 003/120  train=1.1471  triplet=1.1471  val_loss=5.2910  val_eer=0.4210  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.4210 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.659, loss=0.9910]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=0.659, loss=0.9910]
#  33%|███▎      | 2/6 [00:03<00:07,  1.79s/batch, acc=0.659, loss=0.9910]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.659, loss=0.9910]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.659, loss=0.9910]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.659, loss=0.9910]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0

#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0019]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0019]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0019]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0019]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.3989]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.895, loss=0.3989]
#
# P1 Epoch 036/120  train=0.0023  triplet=0.0023  val_loss=0.3989  val_eer=0.0425  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0018]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0018]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0018]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0018]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0018]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0018]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0018]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.3991]
# 100%|██████████| 1/1 [00:00<00:00,  2.29batch/s, acc=0.900, loss=0.3991]
#
# P1 Epoch 037/120  train=0.0020  triplet=0.0020  val_loss=0.3991  val_eer=0.0427  lr=2.00e-03  t=11.6s
#   Terbaik: val_eer=0.0427 smoothed=0.0428 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0023]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=1.000, loss=0.0023]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0023]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0023]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0023]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0023]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0023]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=0.3850]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=0.3850]
#
# P1 Epoch 038/120  train=0.0019  triplet=0.0019  val_loss=0.3850  val_eer=0.0506  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0045]
#  17%|█▋        | 1/6 [00:02<00:11,  2.26s/batch, acc=0.999, loss=0.0045]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.999, loss=0.0045]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.999, loss=0.0045]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.999, loss=0.0045]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.999, loss=0.0045]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.999, loss=0.0045]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=0.3666]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=0.3666]
#
# P1 Epoch 039/120  train=0.0023  triplet=0.0023  val_loss=0.3666  val_eer=0.0484  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0028]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=1.000, loss=0.0028]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0028]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0028]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0028]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0028]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0028]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.3902]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.900, loss=0.3902]
#
# P1 Epoch 040/120  train=0.0024  triplet=0.0024  val_loss=0.3902  val_eer=0.0387  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0019]
#  17%|█▋        | 1/6 [00:02<00:11,  2.26s/batch, acc=1.000, loss=0.0019]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0019]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0019]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0019]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0019]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0019]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.4347]
# 100%|██████████| 1/1 [00:00<00:00,  2.29batch/s, acc=0.900, loss=0.4347]
#
# P1 Epoch 041/120  train=0.0020  triplet=0.0020  val_loss=0.4347  val_eer=0.0401  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0016]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=1.000, loss=0.0016]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0016]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0016]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0016]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0016]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0016]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.4211]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.895, loss=0.4211]
#
# P1 Epoch 042/120  train=0.0021  triplet=0.0021  val_loss=0.4211  val_eer=0.0396  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0033]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.999, loss=0.0033]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.999, loss=0.0033]
# ...
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.877, loss=2.1522]
#
# P2 Epoch 014/30  train=0.0030  triplet=0.0030  val_loss=2.1522  val_eer=0.0184  lr=2.21e-04  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0022]
#  17%|█▋        | 1/6 [00:02<00:11,  2.40s/batch, acc=0.999, loss=0.0022]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=0.999, loss=0.0022]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=0.999, loss=0.0022]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.999, loss=0.0022]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0022]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.999, loss=0.0022]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.3567]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.3567]
#
# P2 Epoch 015/30  train=0.0024  triplet=0.0024  val_loss=2.3567  val_eer=0.0272  lr=2.00e-04  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0028]
#  17%|█▋        | 1/6 [00:02<00:11,  2.35s/batch, acc=0.999, loss=0.0028]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=0.999, loss=0.0028]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.999, loss=0.0028]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0028]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0028]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0028]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.5117]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.868, loss=2.5117]
#
# P2 Epoch 016/30  train=0.0032  triplet=0.0032  val_loss=2.5117  val_eer=0.0272  lr=1.80e-04  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0061]
#  17%|█▋        | 1/6 [00:02<00:11,  2.36s/batch, acc=0.999, loss=0.0061]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=0.999, loss=0.0061]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.999, loss=0.0061]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0061]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0061]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0061]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.859, loss=2.2849]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.859, loss=2.2849]
#
# P2 Epoch 017/30  train=0.0059  triplet=0.0059  val_loss=2.2849  val_eer=0.0301  lr=1.59e-04  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0032]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=0.999, loss=0.0032]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=0.999, loss=0.0032]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=0.999, loss=0.0032]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.999, loss=0.0032]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0032]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.999, loss=0.0032]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.873, loss=2.0361]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.873, loss=2.0361]
#
# P2 Epoch 018/30  train=0.0034  triplet=0.0034  val_loss=2.0361  val_eer=0.0382  lr=1.39e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0014]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=0.999, loss=0.0014]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=0.999, loss=0.0014]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=0.999, loss=0.0014]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.999, loss=0.0014]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0014]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.999, loss=0.0014]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.882, loss=2.0518]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=2.0518]
#
# P2 Epoch 019/30  train=0.0026  triplet=0.0026  val_loss=2.0518  val_eer=0.0296  lr=1.19e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0006]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=1.000, loss=0.0006]
#  33%|███▎      | 2/6 [00:03<00:07,  1.85s/batch, acc=1.000, loss=0.0006]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0006]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0006]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0006]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0006]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.2238]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.868, loss=2.2238]
#
# P2 Epoch 020/30  train=0.0023  triplet=0.0023  val_loss=2.2238  val_eer=0.0337  lr=1.01e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0109]
#  17%|█▋        | 1/6 [00:02<00:12,  2.44s/batch, acc=0.998, loss=0.0109]
#  33%|███▎      | 2/6 [00:03<00:07,  1.85s/batch, acc=0.998, loss=0.0109]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=0.998, loss=0.0109]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.998, loss=0.0109]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.998, loss=0.0109]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.998, loss=0.0109]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.845, loss=2.2881]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.845, loss=2.2881]
#
# P2 Epoch 021/30  train=0.0047  triplet=0.0047  val_loss=2.2881  val_eer=0.0232  lr=8.32e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0001]
#  17%|█▋        | 1/6 [00:02<00:12,  2.40s/batch, acc=1.000, loss=0.0001]
#  33%|███▎      | 2/6 [00:03<00:07,  1.84s/batch, acc=1.000, loss=0.0001]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=1.000, loss=0.0001]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0001]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0001]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0001]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.864, loss=2.3215]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.864, loss=2.3215]
#
# P2 Epoch 022/30  train=0.0015  triplet=0.0015  val_loss=2.3215  val_eer=0.0279  lr=6.70e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0016]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=1.000, loss=0.0016]
#  33%|███▎      | 2/6 [00:03<00:07,  1.86s/batch, acc=1.000, loss=0.0016]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0016]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0016]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0016]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0016]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.873, loss=2.2427]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.873, loss=2.2427]
#
# P2 Epoch 023/30  train=0.0018  triplet=0.0018  val_loss=2.2427  val_eer=0.0303  lr=5.22e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0005]
#  17%|█▋        | 1/6 [00:02<00:11,  2.36s/batch, acc=1.000, loss=0.0005]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=1.000, loss=0.0005]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=1.000, loss=0.0005]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0005]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0005]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0005]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.886, loss=2.1053]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.886, loss=2.1053]
#
# P2 Epoch 024/30  train=0.0021  triplet=0.0021  val_loss=2.1053  val_eer=0.0289  lr=3.91e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0027]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=0.999, loss=0.0027]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=0.999, loss=0.0027]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=0.999, loss=0.0027]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.999, loss=0.0027]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0027]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=0.999, loss=0.0027]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.873, loss=2.2111]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.873, loss=2.2111]
#
# P2 Epoch 025/30  train=0.0015  triplet=0.0015  val_loss=2.2111  val_eer=0.0411  lr=2.77e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0070]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=0.999, loss=0.0070]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=0.999, loss=0.0070]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=0.999, loss=0.0070]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.999, loss=0.0070]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0070]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=0.999, loss=0.0070]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.0371]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.0371]
#
# P2 Epoch 026/30  train=0.0026  triplet=0.0026  val_loss=2.0371  val_eer=0.0208  lr=1.82e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0002]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=1.000, loss=0.0002]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=1.000, loss=0.0002]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=1.000, loss=0.0002]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0002]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0002]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0002]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.2658]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.2658]
#
# P2 Epoch 027/30  train=0.0011  triplet=0.0011  val_loss=2.2658  val_eer=0.0301  lr=1.08e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0021]
#  17%|█▋        | 1/6 [00:02<00:12,  2.49s/batch, acc=1.000, loss=0.0021]
#  33%|███▎      | 2/6 [00:03<00:07,  1.87s/batch, acc=1.000, loss=0.0021]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=1.000, loss=0.0021]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0021]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0021]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0021]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.3209]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.868, loss=2.3209]
#
# P2 Epoch 028/30  train=0.0022  triplet=0.0022  val_loss=2.3209  val_eer=0.0217  lr=5.36e-06  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0012]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=1.000, loss=0.0012]
#  33%|███▎      | 2/6 [00:03<00:07,  1.85s/batch, acc=1.000, loss=0.0012]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0012]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0012]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0012]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0012]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=2.1014]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.891, loss=2.1014]
#
# P2 Epoch 029/30  train=0.0010  triplet=0.0010  val_loss=2.1014  val_eer=0.0403  lr=2.09e-06  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0001]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=1.000, loss=0.0001]
#  33%|███▎      | 2/6 [00:03<00:07,  1.86s/batch, acc=1.000, loss=0.0001]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0001]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0001]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0001]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0001]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.3809]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.868, loss=2.3809]
#
# P2 Epoch 030/30  train=0.0006  triplet=0.0006  val_loss=2.3809  val_eer=0.0224  lr=1.00e-06  t=11.8s
# [v7.2.0 perf] train_wall=1794.6s  peak_gpu=78048.5MB  n_train_frames=871
#
# Training selesai. Best pair_eer = 0.0205
#
# Training selesai: 12 unit OK (dari 12).
