# %% [markdown]
# # v8 TRAIN — seed 123 (faktorial alignment × loss)
# Shell tipis: semua logika di `v8_lib.py`. File ini KHUSUS seed **123** (1 file per runtime → tak konflik antar-runtime paralel).
# Jalankan Run-all. Checkpoint → Google Drive; resume otomatis (gate `perf.json`).

# %% [markdown]
# ## 1. Clone repo (branch main)

# %%
from google.colab import userdata
import os, sys, subprocess
from pathlib import Path
TOKEN = userdata.get('GITHUB_TOKEN'); os.environ['GITHUB_TOKEN'] = TOKEN
REPO = Path('/content/Thesis'); URL = f'https://{TOKEN}@github.com/RZulfikri/Thesis.git'
if not REPO.exists():
    subprocess.run(['git','clone','--branch','main',URL,str(REPO)], check=True)
else:
    subprocess.run(['git','-C',str(REPO),'fetch','origin','main'], check=True)
    subprocess.run(['git','-C',str(REPO),'checkout','main'], check=True)
    subprocess.run(['git','-C',str(REPO),'pull','origin','main'], check=True)
subprocess.run(['git','-C',str(REPO),'config','user.email','colab@thesis.local'])
subprocess.run(['git','-C',str(REPO),'config','user.name','Colab Runner'])
sys.path.insert(0, str(REPO/'3DCNN'/'collab'))
print('clone OK ->', REPO)
# Out:
# clone OK -> /content/Thesis

# %% [markdown]
# ## 2. Setup (Drive + dataset + autotune GPU)

# %%
import v8_lib as L
L.setup(github_token=os.environ['GITHUB_TOKEN'])
# Out:
# Mounted at /content/drive
# Device: cuda | REPO_DIR=/content/Thesis
# RUNS_DIR (Drive): /content/drive/MyDrive/PointNetPalm/runs/v8_factorial
# ANA_DIR (git):    /content/Thesis/3DCNN/analysis/v8_factorial_20260628_035725
# [deps] install: open3d ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 150.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 164.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 179.7 MB/s eta 0:00:00
# [data] RESTORE dataset dari Drive cache (tanpa regenerate) ...
# [data] restored: 2131 frame
# [data] siap: 2131 frame
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (95.6 GB) | AMP=bf16 | BS(fixed)=3072 | workers=8 | REPEAT=24 | N_POINTS=8192
# [LowData-Sessions] train   : 88 sesi
# [LowData-Sessions] val     : 22 sesi
# [LowData-Sessions] test    : 22 sesi
# [LowData-Sessions] holdout : 33 sesi
#   train   : 11 subjek, 88 sesi
#   val     : 11 subjek, 22 sesi
#   test    : 11 subjek, 22 sesi
#   holdout : 11 subjek, 33 sesi
# [setup] selesai.

# %% [markdown]
# ## 3. Training — 12 config × seed 123

# %%
L.train(seeds=[123])   # 12 config (A0..A5 × softmax/arcface) untuk seed 123
# Out:
# Streaming output truncated to the last 5000 lines.
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0002]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0002]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0002]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0002]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0002]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0002]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0002]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.918, loss=2.0609]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.918, loss=2.0609]
#
# P2 Epoch 029/30  train=0.0003  triplet=0.0003  val_loss=2.0609  val_eer=0.0391  lr=2.09e-06  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0003]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0003]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0003]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0003]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0003]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0003]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0003]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=2.0749]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=2.0749]
#
# P2 Epoch 030/30  train=0.0004  triplet=0.0004  val_loss=2.0749  val_eer=0.0403  lr=1.00e-06  t=11.6s
# [v7.2.0 perf] train_wall=1791.1s  peak_gpu=78048.5MB  n_train_frames=871
#
# Training selesai. Best pair_eer = 0.0215
#
# ============================================================
# TRAIN A5_softmax | repr=align_anatomical | loss=arcface_true m=0.0 | seed=123
# ============================================================
# $ PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True /usr/bin/python3 /content/Thesis/3DCNN/train.py --data_dir /content/Thesis/3DCNN/dataset --output_dir /content/drive/MyDrive/PointNetPalm/runs/v8_factorial/A5_softmax/seed_123 --seed 123 --fixed_split --frames-per-session 1 --frame-mode all --repr-mode align_anatomical --loss arcface_true --arcface-variant true --arcface-margin 0.0 --arcface-scale 30.0 --val-metric pair_eer --no-early-stop --epochs 120 --finetune_epochs 30 --lr 0.004 --finetune_lr 0.0004 --batch_size 3072 --n_points 8192 --num_workers 8 --repeat 24 --amp bf16 --preload-augment --siamese-mode concat
#
# 2026-06-28 08:58:44.101701: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-28 08:58:44.135418: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Auto-config] 96GB class (NVIDIA RTX PRO 6000 Blackwell Server Edition, CC=12.0) | VRAM=95.6GB | CPU=48 core | RAM=176.9GB
#               batch_size=3072, num_workers=8, n_points=8192, lr=0.002, finetune_lr=0.0002
# Device: cuda
# [Seed] RNG seeds set to 123
# [CUDA] cudnn.benchmark=True, TF32=enabled
# Layout data: frame (single-frame)
#
# [v7.2.0] Low-data ALL-FRAME regime: repr_mode=align_anatomical
# [LowData-Sessions] train   : 88 sesi
# [LowData-Sessions] val     : 22 sesi
# [LowData-Sessions] test    : 22 sesi
# [LowData-Sessions] holdout : 33 sesi
# [LowData-AllFrames] train   : 871 frames
# [LowData-AllFrames] val     : 220 frames
# [LowData-AllFrames] test    : 220 frames
# [LowData-AllFrames] holdout : 330 frames
#
# Split (low-data, deterministic chronological):
#   aisah              train= 80  val= 20  test= 20  holdout=30
#   alji               train= 80  val= 20  test= 20  holdout=30
#   chrys              train= 80  val= 20  test= 20  holdout=30
#   fadhil             train= 80  val= 20  test= 20  holdout=30
#   feby               train= 80  val= 20  test= 20  holdout=30
#   gede               train= 80  val= 20  test= 20  holdout=30
#   nola               train= 71  val= 20  test= 20  holdout=30
#   rahmat             train= 80  val= 20  test= 20  holdout=30
#   reysa              train= 80  val= 20  test= 20  holdout=30
#   taufik             train= 80  val= 20  test= 20  holdout=30
#   yanuar             train= 80  val= 20  test= 20  holdout=30
#
# splits.json disimpan di: /content/drive/MyDrive/PointNetPalm/runs/v8_factorial/A5_softmax/seed_123/splits.json
# [Dataset] mode=arcface_true  repeat=24  preload_augment=True
# PalmFrameDataset (PRELOAD): precomputing 20904 augmented variants ...
#   Preload selesai: 20904 items, ~3920.5 MB di RAM
# PalmFrameDataset: 220 unique frames, 11 labels, repeat=1 → len(dataset)=220
# [Loss] margin head 'arcface_true' (variant=true, m=0.0, s=30.0, K=3); criterion=cross-entropy
# [Siamese] mode = concat, loss = arcface_true, aux_loss = False
# [ValPairMetric] Preloading 220 frames for val pair computation...
# [ValPairMetric] 2190 pairs ready (2090 genuine, 100 impostor)
#
# --- Phase 1: Main Training (lr=4.00e-03, epochs=120) ---
# [AMP] Mixed precision: bf16 (no GradScaler, optimal H100/A100)
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:10<?, ?batch/s, acc=0.077, loss=4.9423]
#  17%|█▋        | 1/6 [00:10<00:52, 10.45s/batch, acc=0.077, loss=4.9423]
#  33%|███▎      | 2/6 [00:11<00:20,  5.17s/batch, acc=0.077, loss=4.9423]
#  50%|█████     | 3/6 [00:13<00:10,  3.64s/batch, acc=0.077, loss=4.9423]
#  67%|██████▋   | 4/6 [00:15<00:05,  2.92s/batch, acc=0.077, loss=4.9423]
#  83%|████████▎ | 5/6 [00:17<00:02,  2.52s/batch, acc=0.077, loss=4.9423]
# 100%|██████████| 6/6 [00:19<00:00,  2.28s/batch, acc=0.077, loss=4.9423]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:03<?, ?batch/s, acc=0.091, loss=6.5805]
# 100%|██████████| 1/1 [00:03<00:00,  3.67s/batch, acc=0.091, loss=6.5805]
#
# P1 Epoch 001/120  train=3.8349  triplet=3.8349  val_loss=6.5805  val_eer=0.4895  lr=4.00e-03  t=26.3s
#   [VRAM Peak Ep1] allocated=76.2GB  reserved=80.5GB  (85% of 95GB)
#   Terbaik: val_eer=0.4895 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.345, loss=2.4915]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=0.345, loss=2.4915]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=0.345, loss=2.4915]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.345, loss=2.4915]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.345, loss=2.4915]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.345, loss=2.4915]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=0.345, loss=2.4915]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.091, loss=5.6340]
# 100%|██████████| 1/1 [00:00<00:00,  2.25batch/s, acc=0.091, loss=5.6340]
#
# P1 Epoch 002/120  train=1.8495  triplet=1.8495  val_loss=5.6340  val_eer=0.4909  lr=4.00e-03  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.613, loss=1.2173]
#  17%|█▋        | 1/6 [00:02<00:11,  2.38s/batch, acc=0.613, loss=1.2173]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=0.613, loss=1.2173]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=0.613, loss=1.2173]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.613, loss=1.2173]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.613, loss=1.2173]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.613, loss=1.2173]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.091, loss=6.2790]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.091, loss=6.2790]
#
# P1 Epoch 003/120  train=1.0499  triplet=1.0499  val_loss=6.2790  val_eer=0.4702  lr=4.00e-03  t=11.7s
#   Terbaik: val_eer=0.4702 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.735, loss=0.8647]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=0.735, loss=0.8647]
#  33%|███▎      | 2/6 [00:03<00:07,  1.79s/batch, acc=0.735, loss=0.8647]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.735, loss=0.8647]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.735, loss=0.8647]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.735, loss=0.8647]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.735, loss=0.8647]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.091, loss=6.6896]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.091, loss=6.6896]
#
# P1 Epoch 004/120  train=0.6932  triplet=0.6932  val_loss=6.6896  val_eer=0.3499  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.3499 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.831, loss=0.5429]
#  17%|█▋        | 1/6 [00:02<00:12,  2.41s/batch, acc=0.831, loss=0.5429]
#  33%|███▎      | 2/6 [00:03<00:07,  1.84s/batch, acc=0.831, loss=0.5429]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=0.831, loss=0.5429]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.831, loss=0.5429]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.831, loss=0.5429]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.831, loss=0.5429]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.127, loss=6.5047]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.127, loss=6.5047]
#
# P1 Epoch 005/120  train=0.4432  triplet=0.4432  val_loss=6.5047  val_eer=0.3301  lr=4.00e-03  t=11.7s
#   Terbaik: val_eer=0.3301 smoothed=0.4261 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.912, loss=0.3090]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=0.912, loss=0.3090]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.912, loss=0.3090]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.912, loss=0.3090]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.912, loss=0.3090]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.912, loss=0.3090]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.912, loss=0.3090]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.164, loss=6.0526]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.164, loss=6.0526]
#
# P1 Epoch 006/120  train=0.2815  triplet=0.2815  val_loss=6.0526  val_eer=0.2618  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.2618 smoothed=0.3806 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.925, loss=0.2547]
#  17%|█▋        | 1/6 [00:02<00:11,  2.37s/batch, acc=0.925, loss=0.2547]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=0.925, loss=0.2547]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.925, loss=0.2547]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.925, loss=0.2547]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.925, loss=0.2547]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.925, loss=0.2547]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.255, loss=5.6491]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.255, loss=5.6491]
#
# P1 Epoch 007/120  train=0.1908  triplet=0.1908  val_loss=5.6491  val_eer=0.2112  lr=4.00e-03  t=11.7s
#   Terbaik: val_eer=0.2112 smoothed=0.3246 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.955, loss=0.1558]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=0.955, loss=0.1558]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=0.955, loss=0.1558]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.955, loss=0.1558]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.955, loss=0.1558]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.955, loss=0.1558]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.955, loss=0.1558]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.473, loss=2.9175]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.473, loss=2.9175]
#
# P1 Epoch 008/120  train=0.1238  triplet=0.1238  val_loss=2.9175  val_eer=0.2024  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.2024 smoothed=0.2711 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.967, loss=0.1106]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=0.967, loss=0.1106]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.967, loss=0.1106]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.967, loss=0.1106]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.967, loss=0.1106]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.967, loss=0.1106]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.967, loss=0.1106]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.741, loss=1.0250]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.741, loss=1.0250]
#
# P1 Epoch 009/120  train=0.0860  triplet=0.0860  val_loss=1.0250  val_eer=0.1406  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.1406 smoothed=0.2292 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.985, loss=0.0622]
#  17%|█▋        | 1/6 [00:02<00:11,  2.36s/batch, acc=0.985, loss=0.0622]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=0.985, loss=0.0622]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.985, loss=0.0622]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.985, loss=0.0622]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.985, loss=0.0622]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.985, loss=0.0622]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=0.4222]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=0.4222]
#
# P1 Epoch 010/120  train=0.0562  triplet=0.0562  val_loss=0.4222  val_eer=0.0905  lr=4.00e-03  t=11.7s
#   Terbaik: val_eer=0.0905 smoothed=0.1813 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.987, loss=0.0456]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.987, loss=0.0456]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.987, loss=0.0456]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.987, loss=0.0456]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.987, loss=0.0456]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.987, loss=0.0456]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.987, loss=0.0456]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.3667]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.895, loss=0.3667]
#
# P1 Epoch 011/120  train=0.0494  triplet=0.0494  val_loss=0.3667  val_eer=0.0594  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0594 smoothed=0.1408 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.990, loss=0.0363]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.990, loss=0.0363]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.990, loss=0.0363]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.990, loss=0.0363]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.990, loss=0.0363]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.990, loss=0.0363]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.990, loss=0.0363]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=0.3155]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=0.3155]
#
# P1 Epoch 012/120  train=0.0354  triplet=0.0354  val_loss=0.3155  val_eer=0.0578  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0578 smoothed=0.1101 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.994, loss=0.0236]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=0.994, loss=0.0236]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.994, loss=0.0236]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.994, loss=0.0236]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.994, loss=0.0236]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.994, loss=0.0236]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.994, loss=0.0236]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=0.3209]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=0.3209]
#
# P1 Epoch 013/120  train=0.0270  triplet=0.0270  val_loss=0.3209  val_eer=0.0604  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0604 smoothed=0.0817 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.994, loss=0.0275]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.994, loss=0.0275]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.994, loss=0.0275]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.994, loss=0.0275]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.994, loss=0.0275]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.994, loss=0.0275]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.994, loss=0.0275]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.905, loss=0.3185]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.905, loss=0.3185]
#
# P1 Epoch 014/120  train=0.0208  triplet=0.0208  val_loss=0.3185  val_eer=0.0496  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0496 smoothed=0.0635 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.995, loss=0.0172]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.995, loss=0.0172]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.995, loss=0.0172]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.995, loss=0.0172]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.995, loss=0.0172]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.995, loss=0.0172]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.995, loss=0.0172]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.882, loss=0.4292]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=0.4292]
#
# P1 Epoch 015/120  train=0.0173  triplet=0.0173  val_loss=0.4292  val_eer=0.0504  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0504 smoothed=0.0555 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.996, loss=0.0160]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.996, loss=0.0160]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.996, loss=0.0160]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.996, loss=0.0160]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.996, loss=0.0160]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.996, loss=0.0160]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.996, loss=0.0160]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.918, loss=0.4728]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.918, loss=0.4728]
#
# P1 Epoch 016/120  train=0.0155  triplet=0.0155  val_loss=0.4728  val_eer=0.0704  lr=4.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.997, loss=0.0134]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.997, loss=0.0134]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.997, loss=0.0134]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.997, loss=0.0134]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.997, loss=0.0134]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.997, loss=0.0134]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.997, loss=0.0134]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.3658]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.900, loss=0.3658]
#
# P1 Epoch 017/120  train=0.0127  triplet=0.0127  val_loss=0.3658  val_eer=0.0504  lr=4.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0098]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0098]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0098]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0098]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0098]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0098]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0098]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.2816]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.914, loss=0.2816]
#
# P1 Epoch 018/120  train=0.0111  triplet=0.0111  val_loss=0.2816  val_eer=0.0425  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0425 smoothed=0.0527 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0089]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.999, loss=0.0089]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.999, loss=0.0089]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.999, loss=0.0089]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.999, loss=0.0089]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.999, loss=0.0089]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.999, loss=0.0089]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=0.3400]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=0.3400]
#
# P1 Epoch 019/120  train=0.0091  triplet=0.0091  val_loss=0.3400  val_eer=0.0585  lr=4.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0076]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0076]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0076]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0076]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0076]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0076]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0076]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.4160]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.900, loss=0.4160]
#
# P1 Epoch 020/120  train=0.0082  triplet=0.0082  val_loss=0.4160  val_eer=0.0406  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0406 smoothed=0.0525 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0086]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0086]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0086]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0086]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0086]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0086]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0086]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.3031]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.914, loss=0.3031]
#
# P1 Epoch 021/120  train=0.0092  triplet=0.0092  val_loss=0.3031  val_eer=0.0580  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0580 smoothed=0.0500 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0086]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0086]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0086]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0086]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0086]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0086]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0086]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.927, loss=0.3467]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.927, loss=0.3467]
#
# P1 Epoch 022/120  train=0.0071  triplet=0.0071  val_loss=0.3467  val_eer=0.0492  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0492 smoothed=0.0497 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0050]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=1.000, loss=0.0050]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0050]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0050]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0050]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0050]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0050]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.905, loss=0.3830]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.905, loss=0.3830]
#
# P1 Epoch 023/120  train=0.0064  triplet=0.0064  val_loss=0.3830  val_eer=0.0401  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0401 smoothed=0.0493 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0062]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0062]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0062]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0062]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0062]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0062]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0062]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.3747]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.900, loss=0.3747]
#
# P1 Epoch 024/120  train=0.0059  triplet=0.0059  val_loss=0.3747  val_eer=0.0303  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0303 smoothed=0.0436 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0051]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=1.000, loss=0.0051]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0051]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0051]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0051]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0051]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0051]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.4306]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.914, loss=0.4306]
#
# P1 Epoch 025/120  train=0.0054  triplet=0.0054  val_loss=0.4306  val_eer=0.0401  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0401 smoothed=0.0435 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0083]
#  17%|█▋        | 1/6 [00:02<00:11,  2.27s/batch, acc=0.998, loss=0.0083]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=0.998, loss=0.0083]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=0.998, loss=0.0083]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=0.998, loss=0.0083]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=0.998, loss=0.0083]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=0.998, loss=0.0083]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=0.4891]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=0.4891]
#
# P1 Epoch 026/120  train=0.0054  triplet=0.0054  val_loss=0.4891  val_eer=0.0403  lr=4.00e-03  t=11.6s
#   Terbaik: val_eer=0.0403 smoothed=0.0400 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0052]
#  17%|█▋        | 1/6 [00:02<00:11,  2.37s/batch, acc=0.999, loss=0.0052]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=0.999, loss=0.0052]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.999, loss=0.0052]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0052]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0052]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0052]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.5008]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.895, loss=0.5008]
#
# P1 Epoch 027/120  train=0.0051  triplet=0.0051  val_loss=0.5008  val_eer=0.0284  lr=4.00e-03  t=11.7s
#   Terbaik: val_eer=0.0284 smoothed=0.0358 disimpan
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0052]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=0.999, loss=0.0052]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=0.999, loss=0.0052]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.999, loss=0.0052]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0052]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0052]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0052]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=0.5896]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=0.5896]
#
# P1 Epoch 028/120  train=0.0047  triplet=0.0047  val_loss=0.5896  val_eer=0.0599  lr=4.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0037]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0037]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0037]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0037]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0037]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0037]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0037]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=0.5343]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=0.5343]
#
# P1 Epoch 029/120  train=0.0045  triplet=0.0045  val_loss=0.5343  val_eer=0.0399  lr=4.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0040]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0040]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0040]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0040]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0040]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0040]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0040]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.918, loss=0.4113]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.918, loss=0.4113]
#
# P1 Epoch 030/120  train=0.0039  triplet=0.0039  val_loss=0.4113  val_eer=0.0475  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0031]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0031]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0031]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0031]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0031]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0031]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0031]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.4723]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.914, loss=0.4723]
#
# P1 Epoch 031/120  train=0.0034  triplet=0.0034  val_loss=0.4723  val_eer=0.0422  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0027]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0027]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0027]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0027]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0027]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0027]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0027]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.4738]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.900, loss=0.4738]
#
# P1 Epoch 032/120  train=0.0033  triplet=0.0033  val_loss=0.4738  val_eer=0.0430  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0024]
#  17%|█▋        | 1/6 [00:02<00:11,  2.28s/batch, acc=1.000, loss=0.0024]
#  33%|███▎      | 2/6 [00:03<00:07,  1.78s/batch, acc=1.000, loss=0.0024]
#  50%|█████     | 3/6 [00:05<00:05,  1.79s/batch, acc=1.000, loss=0.0024]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.79s/batch, acc=1.000, loss=0.0024]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.79s/batch, acc=1.000, loss=0.0024]
# 100%|██████████| 6/6 [00:10<00:00,  1.79s/batch, acc=1.000, loss=0.0024]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.905, loss=0.4628]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.905, loss=0.4628]
#
# P1 Epoch 033/120  train=0.0027  triplet=0.0027  val_loss=0.4628  val_eer=0.0294  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0030]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=0.999, loss=0.0030]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=0.999, loss=0.0030]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.999, loss=0.0030]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0030]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0030]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0030]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.4344]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.914, loss=0.4344]
#
# P1 Epoch 034/120  train=0.0028  triplet=0.0028  val_loss=0.4344  val_eer=0.0401  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0021]
#  17%|█▋        | 1/6 [00:02<00:11,  2.37s/batch, acc=1.000, loss=0.0021]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=1.000, loss=0.0021]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=1.000, loss=0.0021]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0021]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0021]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0021]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.909, loss=0.4456]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.909, loss=0.4456]
#
# P1 Epoch 035/120  train=0.0024  triplet=0.0024  val_loss=0.4456  val_eer=0.0389  lr=2.00e-03  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0030]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=0.999, loss=0.0030]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=0.999, loss=0.0030]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.999, loss=0.0030]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0030]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0030]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0030]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.905, loss=0.4487]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.905, loss=0.4487]
#
# P1 Epoch 036/120  train=0.0026  triplet=0.0026  val_loss=0.4487  val_eer=0.0585  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0024]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0024]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0024]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0024]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0024]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0024]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0024]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.900, loss=0.4617]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.900, loss=0.4617]
#
# P1 Epoch 037/120  train=0.0027  triplet=0.0027  val_loss=0.4617  val_eer=0.0317  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0023]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0023]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0023]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0023]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0023]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0023]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0023]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.4850]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.895, loss=0.4850]
#
# P1 Epoch 038/120  train=0.0026  triplet=0.0026  val_loss=0.4850  val_eer=0.0494  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0021]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0021]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0021]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0021]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0021]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0021]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0021]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.4507]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.914, loss=0.4507]
#
# P1 Epoch 039/120  train=0.0021  triplet=0.0021  val_loss=0.4507  val_eer=0.0504  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0027]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0027]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0027]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0027]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0027]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0027]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0027]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.927, loss=0.4794]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.927, loss=0.4794]
#
# P1 Epoch 040/120  train=0.0022  triplet=0.0022  val_loss=0.4794  val_eer=0.0370  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0024]
#  17%|█▋        | 1/6 [00:02<00:11,  2.32s/batch, acc=1.000, loss=0.0024]
#  33%|███▎      | 2/6 [00:03<00:07,  1.80s/batch, acc=1.000, loss=0.0024]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0024]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0024]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0024]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0024]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.895, loss=0.4665]
# 100%|██████████| 1/1 [00:00<00:00,  2.27batch/s, acc=0.895, loss=0.4665]
#
# P1 Epoch 041/120  train=0.0019  triplet=0.0019  val_loss=0.4665  val_eer=0.0401  lr=2.00e-03  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0018]
#  17%|█▋        | 1/6 [00:02<00:11,  2.36s/batch, acc=1.000, loss=0.0018]
#  33%|███▎      | 2/6 [00:03<00:07,  1.82s/batch, acc=1.000, loss=0.0018]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=1.000, loss=0.0018]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0018]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0018]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0018]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.914, loss=0.4550]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.914, loss=0.4550]
#
# P1 Epoch 042/120  train=0.0017  triplet=0.0017  val_loss=0.4550  val_eer=0.0320  lr=2.00e-03  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0012]
# ...
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=2.9084]
#
# P2 Epoch 014/30  train=0.0038  triplet=0.0038  val_loss=2.9084  val_eer=0.0437  lr=2.21e-04  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0033]
#  17%|█▋        | 1/6 [00:02<00:12,  2.51s/batch, acc=1.000, loss=0.0033]
#  33%|███▎      | 2/6 [00:03<00:07,  1.88s/batch, acc=1.000, loss=0.0033]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=1.000, loss=0.0033]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0033]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0033]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=1.000, loss=0.0033]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.864, loss=3.0544]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.864, loss=3.0544]
#
# P2 Epoch 015/30  train=0.0039  triplet=0.0039  val_loss=3.0544  val_eer=0.0422  lr=2.00e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0017]
#  17%|█▋        | 1/6 [00:02<00:12,  2.47s/batch, acc=1.000, loss=0.0017]
#  33%|███▎      | 2/6 [00:03<00:07,  1.86s/batch, acc=1.000, loss=0.0017]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0017]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0017]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0017]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0017]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.882, loss=2.7620]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=2.7620]
#
# P2 Epoch 016/30  train=0.0033  triplet=0.0033  val_loss=2.7620  val_eer=0.0496  lr=1.80e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.998, loss=0.0053]
#  17%|█▋        | 1/6 [00:02<00:12,  2.45s/batch, acc=0.998, loss=0.0053]
#  33%|███▎      | 2/6 [00:03<00:07,  1.86s/batch, acc=0.998, loss=0.0053]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=0.998, loss=0.0053]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.998, loss=0.0053]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.998, loss=0.0053]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.998, loss=0.0053]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.882, loss=2.7525]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=2.7525]
#
# P2 Epoch 017/30  train=0.0030  triplet=0.0030  val_loss=2.7525  val_eer=0.0401  lr=1.59e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0005]
#  17%|█▋        | 1/6 [00:02<00:12,  2.47s/batch, acc=1.000, loss=0.0005]
#  33%|███▎      | 2/6 [00:03<00:07,  1.86s/batch, acc=1.000, loss=0.0005]
#  50%|█████     | 3/6 [00:05<00:05,  1.83s/batch, acc=1.000, loss=0.0005]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0005]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0005]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0005]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.8324]
# 100%|██████████| 1/1 [00:00<00:00,  2.29batch/s, acc=0.868, loss=2.8324]
#
# P2 Epoch 018/30  train=0.0032  triplet=0.0032  val_loss=2.8324  val_eer=0.0530  lr=1.39e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0021]
#  17%|█▋        | 1/6 [00:02<00:12,  2.51s/batch, acc=1.000, loss=0.0021]
#  33%|███▎      | 2/6 [00:03<00:07,  1.88s/batch, acc=1.000, loss=0.0021]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=1.000, loss=0.0021]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=1.000, loss=0.0021]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=1.000, loss=0.0021]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=1.000, loss=0.0021]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.891, loss=2.7316]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.891, loss=2.7316]
#
# P2 Epoch 019/30  train=0.0020  triplet=0.0020  val_loss=2.7316  val_eer=0.0406  lr=1.19e-04  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0002]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=1.000, loss=0.0002]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=1.000, loss=0.0002]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0002]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0002]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0002]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0002]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.6547]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.6547]
#
# P2 Epoch 020/30  train=0.0010  triplet=0.0010  val_loss=2.6547  val_eer=0.0511  lr=1.01e-04  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0012]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=1.000, loss=0.0012]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=1.000, loss=0.0012]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0012]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0012]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0012]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0012]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.6440]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.868, loss=2.6440]
#
# P2 Epoch 021/30  train=0.0023  triplet=0.0023  val_loss=2.6440  val_eer=0.0382  lr=8.32e-05  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0059]
#  17%|█▋        | 1/6 [00:02<00:11,  2.34s/batch, acc=0.999, loss=0.0059]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=0.999, loss=0.0059]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=0.999, loss=0.0059]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=0.999, loss=0.0059]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0059]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=0.999, loss=0.0059]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.8095]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.8095]
#
# P2 Epoch 022/30  train=0.0029  triplet=0.0029  val_loss=2.8095  val_eer=0.0477  lr=6.70e-05  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0011]
#  17%|█▋        | 1/6 [00:02<00:11,  2.38s/batch, acc=0.999, loss=0.0011]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=0.999, loss=0.0011]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=0.999, loss=0.0011]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.999, loss=0.0011]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=0.999, loss=0.0011]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.999, loss=0.0011]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.886, loss=2.8643]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.886, loss=2.8643]
#
# P2 Epoch 023/30  train=0.0010  triplet=0.0010  val_loss=2.8643  val_eer=0.0370  lr=5.22e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0006]
#  17%|█▋        | 1/6 [00:02<00:11,  2.38s/batch, acc=1.000, loss=0.0006]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=1.000, loss=0.0006]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=1.000, loss=0.0006]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0006]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0006]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=1.000, loss=0.0006]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.877, loss=2.7411]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.877, loss=2.7411]
#
# P2 Epoch 024/30  train=0.0009  triplet=0.0009  val_loss=2.7411  val_eer=0.0375  lr=3.91e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0015]
#  17%|█▋        | 1/6 [00:02<00:12,  2.51s/batch, acc=0.999, loss=0.0015]
#  33%|███▎      | 2/6 [00:03<00:07,  1.88s/batch, acc=0.999, loss=0.0015]
#  50%|█████     | 3/6 [00:05<00:05,  1.84s/batch, acc=0.999, loss=0.0015]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.82s/batch, acc=0.999, loss=0.0015]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0015]
# 100%|██████████| 6/6 [00:11<00:00,  1.81s/batch, acc=0.999, loss=0.0015]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.8778]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.868, loss=2.8778]
#
# P2 Epoch 025/30  train=0.0014  triplet=0.0014  val_loss=2.8778  val_eer=0.0525  lr=2.77e-05  t=11.8s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0003]
#  17%|█▋        | 1/6 [00:02<00:11,  2.38s/batch, acc=1.000, loss=0.0003]
#  33%|███▎      | 2/6 [00:03<00:07,  1.83s/batch, acc=1.000, loss=0.0003]
#  50%|█████     | 3/6 [00:05<00:05,  1.81s/batch, acc=1.000, loss=0.0003]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=1.000, loss=0.0003]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0003]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0003]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.868, loss=2.9513]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.868, loss=2.9513]
#
# P2 Epoch 026/30  train=0.0007  triplet=0.0007  val_loss=2.9513  val_eer=0.0334  lr=1.82e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=0.999, loss=0.0068]
#  17%|█▋        | 1/6 [00:02<00:12,  2.43s/batch, acc=0.999, loss=0.0068]
#  33%|███▎      | 2/6 [00:03<00:07,  1.85s/batch, acc=0.999, loss=0.0068]
#  50%|█████     | 3/6 [00:05<00:05,  1.82s/batch, acc=0.999, loss=0.0068]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.81s/batch, acc=0.999, loss=0.0068]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.81s/batch, acc=0.999, loss=0.0068]
# 100%|██████████| 6/6 [00:11<00:00,  1.80s/batch, acc=0.999, loss=0.0068]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.886, loss=2.7148]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.886, loss=2.7148]
#
# P2 Epoch 027/30  train=0.0020  triplet=0.0020  val_loss=2.7148  val_eer=0.0559  lr=1.08e-05  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0013]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=1.000, loss=0.0013]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=1.000, loss=0.0013]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0013]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0013]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0013]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0013]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.882, loss=2.7271]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.882, loss=2.7271]
#
# P2 Epoch 028/30  train=0.0007  triplet=0.0007  val_loss=2.7271  val_eer=0.0496  lr=5.36e-06  t=11.6s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0001]
#  17%|█▋        | 1/6 [00:02<00:11,  2.34s/batch, acc=1.000, loss=0.0001]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=1.000, loss=0.0001]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0001]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0001]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0001]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0001]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.873, loss=2.7278]
# 100%|██████████| 1/1 [00:00<00:00,  2.28batch/s, acc=0.873, loss=2.7278]
#
# P2 Epoch 029/30  train=0.0011  triplet=0.0011  val_loss=2.7278  val_eer=0.0379  lr=2.09e-06  t=11.7s
#
#   0%|          | 0/6 [00:00<?, ?batch/s]
#   0%|          | 0/6 [00:02<?, ?batch/s, acc=1.000, loss=0.0014]
#  17%|█▋        | 1/6 [00:02<00:11,  2.33s/batch, acc=1.000, loss=0.0014]
#  33%|███▎      | 2/6 [00:03<00:07,  1.81s/batch, acc=1.000, loss=0.0014]
#  50%|█████     | 3/6 [00:05<00:05,  1.80s/batch, acc=1.000, loss=0.0014]
#  67%|██████▋   | 4/6 [00:07<00:03,  1.80s/batch, acc=1.000, loss=0.0014]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.80s/batch, acc=1.000, loss=0.0014]
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/batch, acc=1.000, loss=0.0014]
#
#
#   0%|          | 0/1 [00:00<?, ?batch/s]
#   0%|          | 0/1 [00:00<?, ?batch/s, acc=0.873, loss=2.8835]
# 100%|██████████| 1/1 [00:00<00:00,  2.29batch/s, acc=0.873, loss=2.8835]
#
# P2 Epoch 030/30  train=0.0017  triplet=0.0017  val_loss=2.8835  val_eer=0.0415  lr=1.00e-06  t=11.6s
# [v7.2.0 perf] train_wall=1793.1s  peak_gpu=78048.5MB  n_train_frames=871
#
# Training selesai. Best pair_eer = 0.0289
#
# Training selesai: 12 unit OK (dari 12).
